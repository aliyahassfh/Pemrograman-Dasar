# %% [markdown]
# <a href="https://colab.research.google.com/github/aliyahassfh/Pemrograman-Dasar/blob/main/Pertemuan_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A. Soal Esai
#   1. Urutan prioritas operator
#     1. () [] {}
#     2. x[index], x.attr
#     3. await x, f()
#     4. **
#     5. +x, -x, ~x
#     6. *, /, //, %
#     7. +, -
#     8. <<, >>
#     9. &
#     10. ^
#     11. `
#     12. in, not in, is, is not, <, <=, >, >=, !=, ==
#     13. not x
#     14. and
#     15. or
#     16. if...alse
#     17. lambda
#     18. :=
#   Bisa dilihat dari urutan prioritas operator bahwa perkalian (*) memiliki prioritas lebih tinggi daripada perjumlahan (+). Jadi pada 10 + 5 * 2, python menghitung 5 * 2 terlebih dahulu dan hasilnya 10, lalu 10 + 10 = 20, bukan 30.
#   Sumber: pythonforall.com (https://www.pythonforall.com/python/operators/precedence)
#
#   2. Perbedaan antara operator rasional (>, <, ==, dll) dan operator logika (and, or, not) yaitu operator rasional digunakan untuk membandingkan dua nilai dan menghasilkan True atau False, sedangkan operaror logika digunakan untuk menggabungkan atau membalik hasil dari beberapa kondisi
#   Contoh: saat menentukan apakah seseorang boleh masuk ke sebuah acara, misalnya syaratnya umur harus 18 tahun atau lebih dan harus memiliki tiket
#   umur >= 18 and punya_tiket == True
#   umur >=18 dan punya_tiket == True merupakan operator rasional, sedangkan and merupakan operator logika. jadi orang tersebut hanya boleh masuk jika kedua kondisi itu benar.
#
#   3. Contoh kasus di forum stack overflow, seorang programmer membuat program untuk menghitung rata-rata dari tiga nilai. Kode yang dibuat adalah average = scores[0] + scores[1] + scores [2] / 3, tetapi hasilnya salah karena pembagian / dikerjakan lebih dulu daripada perjumlahan +
#   Perbaikan kode: ditulis dengan tanda kurung agar semua nilai dijumlahkan lebih dulu, dengan begitu perjumlahan ketiga nilai baru dibagi 3
#   average = (scores[0] + scores[1] + scores[2]) / 3

# %%
# Nama  : Aliyah Nur Assyfah
# NIM   : 4232501034
# Tanggal : 25 September 2026
# Tujuan: Menghitung operasi aritmatika dari dua bilangan bulat

bilangan1 = int(input("Masukkan bilangan pertama: "))
bilangan2 = int(input("Masukkan bilangan kedua: "))

print("Hasil + :", bilangan1 + bilangan2)
print("Hasil - :", bilangan1 - bilangan2)
print("Hasil * :", bilangan1 * bilangan2)
print("Hasil / :", bilangan1 / bilangan2)
print("Hasil //:", bilangan1 // bilangan2)
print("Hasil % :", bilangan1 % bilangan2)
# Out:
# Masukkan bilangan pertama: 10
# Masukkan bilangan kedua: 34
# Hasil + : 44
# Hasil - : -24
# Hasil * : 340
# Hasil / : 0.29411764705882354
# Hasil //: 0
# Hasil % : 10

# %%
# Nama  : Aliyah Nur Assyfah
# NIM   : 4232501034
# Tanggal : 25 September 2026
# Tujuan: Mengecek apakah nilai ujian termasuk kategori lulus

nilai = int(input("Masukkan nilai ujian: "))

print("Nilai lulus:", nilai >= 60)
# Out:
# Masukkan nilai ujian: 89
# Nilai lulus: True

# %%
# Nama  : Aliyah Nur Assyfah
# NIM   : 4232501034
# Tanggal : 25 September 2026
# Tujuan: Menentukan apakah seseorang boleh mengemudi sendiri

umur = int(input("Masukkan umur: "))
punya_sim = input("Punya SIM? (True/False): ")

boleh_mengemudi = (umur >= 17) and (punya_sim == "True")

print("Boleh mengemudi sendiri:", boleh_mengemudi)
# Out:
# Masukkan umur: 19
# Punya SIM? (True/False): True
# Boleh mengemudi sendiri: True

# %%
# Nama  : Aliyah Nur Assyfah
# NIM   : 4232501034
# Tanggal : 25 September 2026
# Tujuan: Menghitung efisiensi termal sebuah unit pembangkit

energi_input = float(input("Masukkan energi input (MJ): "))
energi_output = float(input("Masukkan energi output (MJ): "))

efisiensi = (energi_output / energi_input) * 100

print(f"Efisiensi termal unit pembangkit adalah {efisiensi:.2f}%")
# Out:
# Masukkan energi input (MJ): 1000
# Masukkan energi output (MJ): 850
# Efisiensi termal unit pembangkit adalah 85.00%

# %%
# Nama  : Aliyah Nur Assyfah
# NIM   : 4232501034
# Tanggal : 25 September 2026
# Tujuan: Menentukan apakah unit pembangkit perlu maintenance

suhu_boiler = float(input("Masukkan suhu boiler (°C): "))
beban_operasi = float(input("Masukkan beban operasi (%): "))

perlu_maintenance = (suhu_boiler > 550) or (beban_operasi > 95)

print(f"Apakah unit pembangkit perlu maintenance? {perlu_maintenance}")
# Out:
# Masukkan suhu boiler (°C): 560
# Masukkan beban operasi (%): 90
# Apakah unit pembangkit perlu maintenance? True
